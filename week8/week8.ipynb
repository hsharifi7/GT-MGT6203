# %%
library(stargazer)

data <- read.csv("contraFactorExample.csv")

# %%
head(data)
# Out:
#   Date      Mom     Mkt_rf  SMB     HML     RF     QMJ     BAB     Contra.rf
# 1 1/31/1980  0.0748  0.0551  0.0168  0.0181 0.0080 -0.0274  0.0263  0.016
# 2 2/29/1980  0.0790 -0.0122 -0.0181  0.0067 0.0089 -0.0200 -0.0153 -0.026
# 3 3/31/1980 -0.0957 -0.1290 -0.0662 -0.0108 0.0121  0.0470 -0.0471 -0.102
# 4 4/30/1980 -0.0039  0.0397  0.0094  0.0114 0.0126 -0.0337  0.0209  0.005
# 5 5/31/1980 -0.0111  0.0526  0.0216  0.0041 0.0081  0.0069  0.0365  0.071
# 6 6/30/1980  0.0155  0.0306  0.0167 -0.0089 0.0061 -0.0111  0.0369  0.006

# %%
# Run factor models
factor1 <- lm(Contra.rf ~ Mkt_rf, data = data)
factor3 <- lm(Contra.rf ~ Mkt_rf+SMB+HML, data = data)
factor4 <- lm(Contra.rf ~ Mkt_rf+SMB+HML+Mom, data = data)
factor6 <- lm(Contra.rf ~ Mkt_rf+SMB+HML+Mom+BAB+QMJ, data = data)
stargazer(factor1, factor3, factor4, factor6, align = TRUE, type = "text", out = "factorModelFull.html")
# Out:
# =========================================================================================================================
#                                                              Dependent variable:
#                     -----------------------------------------------------------------------------------------------------
#                                                                   Contra.rf
#                                (1)                       (2)                      (3)                      (4)
# -------------------------------------------------------------------------------------------------------------------------
# Mkt_rf                       0.901***                  0.885***                 0.913***                 0.914***
#                              (0.019)                   (0.020)                  (0.019)                  (0.022)
#
# SMB                                                     0.048*                   0.042                    0.038
#                                                        (0.029)                  (0.027)                  (0.030)
#
# HML                                                     -0.048                   0.004                   -0.070**
#                                                        (0.030)                  (0.029)                  (0.032)
#
# Mom                                                                             0.132***                 0.096***
#                                                                                 (0.018)                  (0.019)
#
# BAB                                                                                                      0.150***
#                                                                                                          (0.025)
#
# QMJ                                                                                                       -0.011
#                                                                                                          (0.045)
#
# Constant                     0.002***                  0.002***                  0.001                    0.0004
#                              (0.001)                   (0.001)                  (0.001)                  (0.001)
#
# -------------------------------------------------------------------------------------------------------------------------
# Observations                   462                       462                      462                      462
# R2                            0.833                     0.835                    0.852                    0.863
# Adjusted R2                   0.832                     0.834                    0.851                    0.861
# Residual Std. Error      0.018 (df = 460)          0.018 (df = 458)         0.017 (df = 457)         0.016 (df = 455)
# F Statistic         2,288.618*** (df = 1; 460) 773.335*** (df = 3; 458) 658.014*** (df = 4; 457) 478.797*** (df = 6; 455)
# =========================================================================================================================
# Note:                                                                                         *p<0.1; **p<0.05; ***p<0.01
